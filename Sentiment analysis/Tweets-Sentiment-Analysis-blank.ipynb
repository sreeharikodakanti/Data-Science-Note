# %%
# !pip install tweepy
# !pip install textblob

# %%
import re # regular expression / regex
import tweepy #Collect tweets
from tweepy import OAuthHandler # Authentication
from textblob import TextBlob # provides text mining, text analysis and text processing modules

# %%
class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'ts8RhO1B1qIzdSLaDsaise89a'
        consumer_secret = 'A4ZawHMrKiAaoxfQhmjrW5F2gWwgjh9jhCuvczy8cymLaTJfES'
        access_token = '929606650415136768-Ok0ca8lkQk7oD8xNUqKWKg9VyoEXJRV'
        access_token_secret = '5mJm07yiPpvFB7M4Z9l4yaip4k6gvSpL2mEMMs6sEXjqX'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("/@%&", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count = 1000):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
 
        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, count = count)
 
            # parsing tweets one by one
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet
                parsed_tweet = {}
 
                # saving text of tweet
                parsed_tweet['text'] = tweet.text
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                # appending parsed tweet to tweets list
                if tweet.retweet_count > 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)
 
            # return parsed tweets
            return tweets
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))

# %%
def main(querytext):
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    tweets = api.get_tweets(query = querytext, count = 1000)
    print("Queries Text : ", querytext)
    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    # percentage of negative tweets
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
    # percentage of neutral tweets
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
    print("\n\n Total Tweets:",len(tweets))
    # printing first 5 positive tweets
    print("\n\nPositive tweets:")
    for tweet in ptweets[:5]:
        print(tweet['text'])
 
    # printing first 5 negative tweets
    print("\n\nNegative tweets:")
    for tweet in ntweets[:5]:
        print(tweet['text'])

# %%
main('China India Relation')
# Out:
# Queries Text :  China India Relation
# Positive tweets percentage: 45.3125 %
# Negative tweets percentage: 15.625 %
# Neutral tweets percentage: 39.0625 %
#
#
#  Total Tweets: 64
#
#
# Positive tweets:
# Funny!
# Those intelects in #Pakistan trending #BoycottIndianProducts, dont know.. Beggers have no choice!
#
# They need… https://t.co/8Qgze2JWKi
# @China_Amb_India Hope ind chin relation will be much more stronger in coming days.
# @drvox Would be a good subject, esp. in relation to developing countries (China, India, African nations are going t… https://t.co/bSFKIHXXjz
# @salimdotcomrade Your brain is an internal matter for you, but its relation to real world is bilateral issue, china… https://t.co/rF85kuoGuk
# @CalumOakes1 @bencorke @richardcalhoun @rolandmcs And the top 3 don't look promising in terms of trade diplomacy:… https://t.co/ZnjIitjqvr
#
#
# Negative tweets:
# RT @sureshkpujari: Sixth Round of discussion with His Excellency, Song Tao, Hon’ble Minister, IDCPC, China on the organisational structure…
# Sixth Round of discussion with His Excellency, Song Tao, Hon’ble Minister, IDCPC, China on the organisational struc… https://t.co/XJlXzW9HNN
# @ndtv Not only Military but government also need to stand up to thug nation China. China openly come against India… https://t.co/2LM8JkA67p
# @wasee24 @MaaKePakode Other countries just don't mess with us, China and India have neutral relation where we can t… https://t.co/2CpBxQJLxh
# @stjohn121 @withcustardpls @Femi_Sorry @Daily_Express The EU certainly is a dead duck in relation to Dyson exportin… https://t.co/HC9YGHB6Q1

# %%
import time
for i in range(10):
    main("modi")
    time.sleep(2)
# Out:
# Queries Text :  modi
# Positive tweets percentage: 36.26373626373626 %
# Negative tweets percentage: 12.087912087912088 %
# Neutral tweets percentage: 51.64835164835165 %
#
#
#  Total Tweets: 91
#
#
# Positive tweets:
# RT @SoStarMusic: #Kashmir: India’s top court is asked to reverse decision on revoking special status
#
# #KashmirWantsFreedom #Article370
#
# @U…
# Many years from now, if humanity is still around, I hope our kids and grandkids look back upon the Age of Modi as t… https://t.co/O3GK8s8jBZ
# RT @FarooqHKhan: My request to all Pakistanis to welcome Preet Kaur the brilliant Sikh lady and Khalistan activist/ freedom fighter for her…
# @ZaidZamanHamid's account has been withheld in India in response to a legal demand. Learn more.
# RT @RiseofBurnol: @drshamamohd Meanwhile
# Many people are suffering with many kind of diseases
# No health care in India
# Poor are becoming poo…
#
#
# Negative tweets:
