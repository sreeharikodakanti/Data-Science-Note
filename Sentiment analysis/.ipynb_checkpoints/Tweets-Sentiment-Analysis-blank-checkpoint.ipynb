# %%
# !pip install tweepy
# !pip install textblob

# %%
import re # regular expression / regex
import tweepy #Collect tweets
from tweepy import OAuthHandler # Authentication
from textblob import TextBlob # provides text mining, text analysis and text processing modules

# %%
class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'ts8RhO1B1qIzdSLaDsaise89a'
        consumer_secret = 'A4ZawHMrKiAaoxfQhmjrW5F2gWwgjh9jhCuvczy8cymLaTJfES'
        access_token = '929606650415136768-Ok0ca8lkQk7oD8xNUqKWKg9VyoEXJRV'
        access_token_secret = '5mJm07yiPpvFB7M4Z9l4yaip4k6gvSpL2mEMMs6sEXjqX'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("/@%&", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count = 1000):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
 
        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, count = count)
 
            # parsing tweets one by one
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet
                parsed_tweet = {}
 
                # saving text of tweet
                parsed_tweet['text'] = tweet.text
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                # appending parsed tweet to tweets list
                if tweet.retweet_count > 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)
 
            # return parsed tweets
            return tweets
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))

# %%
def main(querytext):
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    tweets = api.get_tweets(query = querytext, count = 1000)
    print("Queries Text : ", querytext)
    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    # percentage of negative tweets
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
    # percentage of neutral tweets
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
    print("\n\n Total Tweets:",len(tweets))
    # printing first 5 positive tweets
    print("\n\nPositive tweets:")
    for tweet in ptweets[:5]:
        print(tweet['text'])
 
    # printing first 5 negative tweets
    print("\n\nNegative tweets:")
    for tweet in ntweets[:5]:
        print(tweet['text'])

# %%
main('GST')
# Out:
# Queries Text :  GST
# Positive tweets percentage: 12.987012987012987 %
# Negative tweets percentage: 14.285714285714286 %
# Neutral tweets percentage: 72.72727272727273 %
#
#
#  Total Tweets: 77
#
#
# Positive tweets:
# RT @DasShaktikanta: Was privileged to work with Shri Arun Jaitley on major reforms like GST,IBC,Monetary Policy framework,FDI liberalisatio…
# RT @taxproindia: Govt irresponsiveness towards GST professionals/taxpayers and GST portal incompetency made a Good Tax reform into blunder.…
# RT @SHALAKHANDI: Immediate Relief Required on urgent basis:-
# A.GST
# 1.Revision of GSTR-3B
# 2.Simplified and Logical Format of Annual Returns.…
# RT @auti_pavan: @JainTax Failures of Governance.. Punishment for Professionals &amp; Taxpayers who believed in Rulers &amp; made GST a huge success…
# RT @bsindia: #ArunJaitley will be remembered as the finance minister during two of the biggest seismic events in India’s economic history -…
#
#
# Negative tweets:
# @goibibo_tech my complaint 29290395 yet to solve, your people are very negative minded &amp; denying GST bill with my c… https://t.co/MeRzAzniTd
# @HMOIndia @gssjodhpur @DrGPradhan @smritiirani @nitin_gadkariGood idea, remove income tax, revise a little GST to c… https://t.co/zCoL14EJmj
# RT @ShrrinG: In less than 5 minutes, he destroyed the entire propaganda on Rafale
#
# He stood with @narendramodi ji after 2002 like a rock
#
# H…
# RT @AmitShah: Be it taking action against black money or realizing the dream of GST, or about demonetisation or giving relief to the common…
# RT @atulmodani: 30 % Taxpayers still not able to File basic Return GSTR 3B , affecting health of #GST
# Max users not able to file #GSTR9 &amp; #…

# %%
import time
for i in range(10):
    main("modi")
    time.sleep(2)
# Out:
# Queries Text :  modi
# Positive tweets percentage: 23.529411764705884 %
# Negative tweets percentage: 23.529411764705884 %
# Neutral tweets percentage: 52.94117647058823 %
#
#
#  Total Tweets: 51
#
#
# Positive tweets:
# RT @Payal_Rohatgi: Actors hire #publicist to make their #personallife public. When #public starts enjoying d gossip of their #personallife,…
# RT @RealHistoryPic: Reel life mein Modi ka role Play krne ka matlab yehi nahi hai ki Real life mein bhi Modi jitna low level jaana hai. htt…
# RT @SwamiGeetika: "Will Rahul Gandhi Make a Good Prime Minister?"
#
# And the Indians long back have made up their mind with a big NO and Modi…
# RT @moulahussain016: @chetan_bhagat I hope Modi wins 2019 and atleast in 2024 he will fight the election without blaming congress but with…
# #ModiAgain@Modi Again clean bowled Lutyens.
#
#
# Negative tweets:
# @IsaArish @finnawoke__ @vladsavov Just like every single Indian politician. Modi isn't a special dumb unicorn.
# @alok_yadav4 @RahulGandhi @Inc You @alok_yadav4 might be wrong as we never know what going to happen in modi tsunami 😂 #AyegaTohModiHi
# RT @nikbhojal: Just by trolling @vivekoberoi , liberandus has opened a Pandora box.
# It was due to sheer hate for Modi that Vivek is being…
# RT @polis_podcast: “What we are seeing today is much worse than the emergency.“ - @pbhushan1 in conversation with @parvaizbukhari  https://…
# RT @humara_desh: In UP alone BJP looks destined to lose half of the seats it won in 2014.
# In 2019, when there is no Modi wave, there is a f…
# Queries Text :  modi
# Positive tweets percentage: 24.528301886792452 %
# Negative tweets percentage: 24.528301886792452 %
# Neutral tweets percentage: 50.943396226415096 %
#
#
#  Total Tweets: 53
#
#
# Positive tweets:
# @ArvindKejriwal Tum me aisa kya hai bhai,
# Ho kaun ..Haare hue CM ya worst CM
#  jo modi sara kaam chor char ke tumhri… https://t.co/A5m6iYlAdD
# RT @Raj_WithRG: In UP alone BJP looks destined to lose half of the seats it won in 2014.
# In 2019, when there is no Modi wave, there is a fa…
# @IsaArish @finnawoke__ @vladsavov Just like every single Indian politician. Modi isn't a special dumb unicorn.
# @alok_yadav4 @RahulGandhi @Inc You @alok_yadav4 might be wrong as we never know what going to happen in modi tsunami 😂 #AyegaTohModiHi
# Queries Text :  modi
# Positive tweets percentage: 34.69387755102041 %
# Negative tweets percentage: 10.204081632653061 %
# Neutral tweets percentage: 55.10204081632653 %
#
#
#  Total Tweets: 49
#
#
# Positive tweets:
# RT @mohitbharatiya_: Sensex, NIFTY
# Is Soaring High,
# Silent voters &amp; BJP party workers,
# Roaring high,
# Modi Wave is touching the sky .
# RT @dhruv_rathee: LOL
#
# Vivek Oberoi is so deeply immersed in his acting role, that he is behaving like Modi in real life also
#
# 😂👇 https://…
# RT @SirPareshRawal: For good health of Modi lovers ...!😁 https://t.co/sMKDGfm5pb
# @arunjaitley These exit polls are made so that BJP can easily manipulate EVM machines. Is desh mein har insan bewak… https://t.co/Yh55VFMxXM
# RT @MrsGandhi: Narendra Modi’s 2019 Lok Sabha campaign: The art of management, grit and a lesson from the Bhagvad Gita. Some excellent poin…
#
#
# Negative tweets:
# RT @polis_podcast: “What we are seeing today is much worse than the emergency.“ - @pbhushan1 in conversation with @parvaizbukhari  https://…
# @ArvindKejriwal Tum me aisa kya hai bhai,
# Ho kaun ..Haare hue CM ya worst CM
#  jo modi sara kaam chor char ke tumhri… https://t.co/A5m6iYlAdD
# RT @Raj_WithRG: In UP alone BJP looks destined to lose half of the seats it won in 2014.
# In 2019, when there is no Modi wave, there is a fa…
# @IsaArish @finnawoke__ @vladsavov Just like every single Indian politician. Modi isn't a special dumb unicorn.
# @alok_yadav4 @RahulGandhi @Inc You @alok_yadav4 might be wrong as we never know what going to happen in modi tsunami 😂 #AyegaTohModiHi
# Queries Text :  modi
# Positive tweets percentage: 34.69387755102041 %
# Negative tweets percentage: 10.204081632653061 %
# Neutral tweets percentage: 55.10204081632653 %
#
#
#  Total Tweets: 49
#
#
# Positive tweets:
# RT @ShekharINC: #WithRGExitPoll seems to be the only exit poll that is showing the ground realities.
# These General Elections happened at a…
# RT @mohitbharatiya_: Sensex, NIFTY
# Is Soaring High,
# Silent voters &amp; BJP party workers,
# Roaring high,
# Modi Wave is touching the sky .
# RT @dhruv_rathee: LOL
#
# Vivek Oberoi is so deeply immersed in his acting role, that he is behaving like Modi in real life also
#
# 😂👇 https://…
# RT @SirPareshRawal: For good health of Modi lovers ...!😁 https://t.co/sMKDGfm5pb
# @arunjaitley These exit polls are made so that BJP can easily manipulate EVM machines. Is desh mein har insan bewak… https://t.co/Yh55VFMxXM
#
#
# Negative tweets:
# RT @polis_podcast: “What we are seeing today is much worse than the emergency.“ - @pbhushan1 in conversation with @parvaizbukhari  https://…
# @ArvindKejriwal Tum me aisa kya hai bhai,
# Ho kaun ..Haare hue CM ya worst CM
#  jo modi sara kaam chor char ke tumhri… https://t.co/A5m6iYlAdD
# RT @Raj_WithRG: In UP alone BJP looks destined to lose half of the seats it won in 2014.
# In 2019, when there is no Modi wave, there is a fa…
# @IsaArish @finnawoke__ @vladsavov Just like every single Indian politician. Modi isn't a special dumb unicorn.
# @alok_yadav4 @RahulGandhi @Inc You @alok_yadav4 might be wrong as we never know what going to happen in modi tsunami 😂 #AyegaTohModiHi
# Queries Text :  modi
# Positive tweets percentage: 34.0 %
# Negative tweets percentage: 10.0 %
# Neutral tweets percentage: 56.0 %
#
#
#  Total Tweets: 50
#
#
# Positive tweets:
# RT @VijaySh32608519: I think this Oberoi fellow  was picked up for this role in Modi's biopic because there was the close intellectual ,  p…
# RT @sumitkashyapjha: As far as I am concerned,I still think the same
#
# Congress 120+-5
# BJP 180+-5
#
# Rest we will see what happens on May 23rd…
# RT @ShekharINC: #WithRGExitPoll seems to be the only exit poll that is showing the ground realities.
# These General Elections happened at a…
# RT @mohitbharatiya_: Sensex, NIFTY
# Is Soaring High,
# Silent voters &amp; BJP party workers,
# Roaring high,
# Modi Wave is touching the sky .
# RT @dhruv_rathee: LOL
#
# Vivek Oberoi is so deeply immersed in his acting role, that he is behaving like Modi in real life also
#
# 😂👇 https://…
#
#
# Negative tweets:
# RT @polis_podcast: “What we are seeing today is much worse than the emergency.“ - @pbhushan1 in conversation with @parvaizbukhari  https://…
# @ArvindKejriwal Tum me aisa kya hai bhai,
# Ho kaun ..Haare hue CM ya worst CM
#  jo modi sara kaam chor char ke tumhri… https://t.co/A5m6iYlAdD
# RT @Raj_WithRG: In UP alone BJP looks destined to lose half of the seats it won in 2014.
# In 2019, when there is no Modi wave, there is a fa…
# @IsaArish @finnawoke__ @vladsavov Just like every single Indian politician. Modi isn't a special dumb unicorn.
# @alok_yadav4 @RahulGandhi @Inc You @alok_yadav4 might be wrong as we never know what going to happen in modi tsunami 😂 #AyegaTohModiHi
# Queries Text :  modi
# Positive tweets percentage: 32.0 %
# Negative tweets percentage: 12.0 %
# Neutral tweets percentage: 56.0 %
#
#
#  Total Tweets: 50
#
#
# Positive tweets:
# RT @kktotlani: @VeenaSachdeva8 @republic @AmitShah @BJP4Haryana @narendramodi @Arnav You are right Veena but main reason was NDA succeeded…
# RT @VijaySh32608519: I think this Oberoi fellow  was picked up for this role in Modi's biopic because there was the close intellectual ,  p…
# RT @sumitkashyapjha: As far as I am concerned,I still think the same
#
# Congress 120+-5
# BJP 180+-5
#
# Rest we will see what happens on May 23rd…
# RT @ShekharINC: #WithRGExitPoll seems to be the only exit poll that is showing the ground realities.
# These General Elections happened at a…
# RT @mohitbharatiya_: Sensex, NIFTY
# Is Soaring High,
# Silent voters &amp; BJP party workers,
# Roaring high,
# Modi Wave is touching the sky .
#
#
# Negative tweets:
# RT @puntinational: If I wanted to commit suicide, I'd climb up Modi’s propaganda level and jump to his achievement level.
# RT @NewIndianXpress: " #BJP neither became Atal or Advaniji's party in the past, nor it can ever be only Amit Shah or Narendra Modi's party…
# RT @polis_podcast: “What we are seeing today is much worse than the emergency.“ - @pbhushan1 in conversation with @parvaizbukhari  https://…
# @ArvindKejriwal Tum me aisa kya hai bhai,
# Ho kaun ..Haare hue CM ya worst CM
#  jo modi sara kaam chor char ke tumhri… https://t.co/A5m6iYlAdD
# RT @Raj_WithRG: In UP alone BJP looks destined to lose half of the seats it won in 2014.
# In 2019, when there is no Modi wave, there is a fa…
