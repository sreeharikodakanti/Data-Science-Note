# %%
import pandas as pd

# %%
data = pd.read_excel('service-data.xlsx',skipinitialspace=True)
data.head()
# Out:
#   Invoice Date Job Card Date Business Partner Name Vehicle No.  \
# 0   2017-05-30    2017-05-30        shivXXXXXXXXXX  KA03MFXXXX
# 1   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 2   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 3   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 4   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
#
#               Vehicle Model  Current KM Reading INVOICE LINE TEXT
# 0  BAJAJ AVENGER STREET 220             50000.0        ENGINE OIL
# 1       BAJAJ PULSAR NS 200               758.0        ENGINE OIL
# 2       BAJAJ PULSAR NS 200               758.0            POLISH
# 3       BAJAJ PULSAR NS 200               758.0       CONSUMABLES
# 4       BAJAJ PULSAR NS 200               758.0       COOLANT OIL

# %%
type(data.iloc[1,1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# plt.plot(data.iloc[:,-1])

# %%
data['INVOICE LINE TEXT'].count().sum()

# data['Invoice Date'].dt.year
# Out:
# 28449

# %%
forecastOne = data[['Invoice Date','INVOICE LINE TEXT']]

# %%
forecastOne = forecastOne.sort_values('Invoice Date')

# %%
forecastOne.head()
# Out:
#    Invoice Date  INVOICE LINE TEXT
# 0    2017-05-30         ENGINE OIL
# 16   2017-05-31  CHAIN LUBRICATION
# 15   2017-05-31             3M OIL
# 14   2017-05-31         ENGINE OIL
# 13   2017-05-31         ENGINE OIL

# %%
column_name = ['Date','Stock']
forecastOne.columns = column_name

# %%
# forecastOne.head()

# %%
forecastOne.loc[forecastOne.Stock == 'POLISH', 'Stock'] = 1
forecastOne.loc[forecastOne.Stock != 1, 'Stock'] = 0

# %%
# forecastOne.set_index('Date', inplace = True)
# forecastOne.head()
# forecastOne["Date"] = forecastOne['Date'].astype(str)
# forecastOne.Date = forecastOne['Date'].apply(lambda x: datetime.strptime(x, '%Y%m'))

# %%
# forecastOne.head(60)
# forecastOne.loc[forecastOne.Stock == 1].shape

# %%
# forecastOne= forecastOne.sort_index()
forecastOne = forecastOne[:-3]

# %%
# plt.plot(forecastOne.iloc[1:10,0], forecastOne.iloc[1:10,1])
# forecastOne.head()

# %%
year = 2017
month = 5
tempYear = 0
tempMonth = 0
stockCount = 0
dateColumn = []
stockColumn = []
for i, j in forecastOne.iterrows():
    tempYear = j.Date.year
    tempMonth = j.Date.month
    
    
    if(tempYear == year and tempMonth == month):
        stockCount += j.Stock
    else:
        dateColumn.append(str(year)+"-"+str(month)+"-1")
        stockColumn.append(stockCount)
        stockCount = 0
        year = tempYear
        month = tempMonth
        stockCount += j.Stock
print(stockColumn)
# Out:
# [0, 66, 67, 52, 50, 46, 66, 52, 40, 49, 66, 71, 55, 46, 51, 60, 87, 97, 97, 114]

# %%
print(dateColumn)
# Out:
# ['2017-5-1', '2017-6-1', '2017-7-1', '2017-8-1', '2017-9-1', '2017-10-1', '2017-11-1', '2017-12-1', '2018-1-1', '2018-2-1', '2018-3-1', '2018-4-1', '2018-5-1', '2018-6-1', '2018-7-1', '2018-8-1', '2018-9-1', '2018-10-1', '2018-11-1', '2018-12-1']

# %%
final_dict = {'Date':dateColumn,'Stock':stockColumn}

# %%
from pandas import datetime
def parser(x):
    return datetime.strptime(x,'%Y-%m-%d')
engineOil = pd.DataFrame(final_dict)
engineOil.Date = engineOil.Date.apply(lambda d: datetime.strptime(d, "%Y-%m-%d"))
# engineOil.index = engineOil.Date
engineOil.set_index('Date', inplace = True)
engineOil.head()
# Out:
#             Stock
# Date
# 2017-05-01      0
# 2017-06-01     66
# 2017-07-01     67
# 2017-08-01     52
# 2017-09-01     50

# %%
# forecastOne.head()
import matplotlib.pyplot as plt
plt.plot(engineOil)

# %%
engineOil_diff = engineOil.diff(periods=1)
engineOil_diff = engineOil_diff[1:]
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(engineOil)

# %%
plot_acf(engineOil_diff)

# %%
X = engineOil.values
print(X.shape)
from sklearn.model_selection import train_test_split
train = X[0:16]
test = X[16:]
# print(test)
# train, test = train_test_split(X,test_size = 0.2)
print(train)
# print(X_train.shape, x_test.shape)
# Out:
# (20, 1)
# [[ 0]
#  [66]
#  [67]
#  [52]
#  [50]
#  [46]
#  [66]
#  [52]
#  [40]
#  [49]
#  [66]
#  [71]
#  [55]
#  [46]
#  [51]
#  [60]]

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
def findPDQ():
    p=0
    d=0
    q=0
    min_value_aic = float("inf")
    for i in range(0,5):
        for j in range(0,5):
            for k in range(0,5):
                try:
                    model_arima = ARIMA(train,order = (i,j,k))
                    model_arima_fit = model_arima.fit()
                    aic = model_arima_fit.aic
                    if aic<min_value_aic:
                        min_value_aic = aic
                        p=i
                        d=j
                        q=k
                except:
                    continue
    return [p,d,q]

# %%
pdq = findPDQ();
# Out:
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
print(pdq)
model_arima = ARIMA(train,order = (pdq[0], pdq[1], pdq[2]))
model_arima_fit = model_arima.fit()
aic = model_arima_fit.aic
print(aic)
predictions = []
# Out:
# [0, 2, 3]
# 131.01525015324884
# /home/skdie/anaconda3/envs/datamites/lib/python3.7/site-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
predictions = model_arima_fit.forecast(steps = 4)[0]

# %%
print(predictions,test)
# Out:
# [48.61355567 33.90485802 27.29906837 19.93931966] [[ 87]
#  [ 97]
#  [ 97]
#  [114]]

# %%
plt.plot(test)
plt.plot(predictions, color = 'red')

# %%
type(forecastOne['Date'])
# Out:
# pandas.core.series.Series

# %%
# forecastOne.head()
import seaborn as sn
sn.countplot(forecastOne.Stock)

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
columnNames = ['Date','Stock']

# %%
forecastOne.columns = columnNames

# %%
forecastOne.head()
# Out:
#         Date  Stock
# 0 2017-05-30      1
# 1 2017-06-02      1
# 2 2017-06-02      0
# 3 2017-06-02      0
# 4 2017-06-02      0

# %%
# import seaborn as sn
# sn.countplot(forecastOne[forecastOne.Stock=='ENGINE OIL'])

# %%
forecastOne['Date'] = parser(forecastOne['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-241-e78efe5500bc> in <module>
# ----> 1 forecastOne['Date'] = parser(forecastOne['Date'])
#
# <ipython-input-239-ed52b38249ac> in parser(x)
#       1 from pandas import datetime
#       2 def parser(x):
# ----> 3     return datetime.strptime(x,'%Y-%m-%d')
#       4 data = pd.read_excel('service-data.xlsx',skipinitialspace=True,parse_dates=[0], parser = True)
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
import matplotlib.pyplot as plt
plt.plot(forecastOne[1:5]);
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fde14ad05f0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1429     def __call__(self):
#    1430         'Return the locations of the ticks'
# -> 1431         self.refresh()
#    1432         return self._locator()
#    1433
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1449     def refresh(self):
#    1450         'Refresh internal information based on current limits.'
# -> 1451         dmin, dmax = self.viewlim_to_dt()
#    1452         self._locator = self.get_locator(dmin, dmax)
#    1453
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1200                              'often happens if you pass a non-datetime '
#    1201                              'value to an axis that has datetime units'
# -> 1202                              .format(vmin))
#    1203         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1204
#
# ValueError: view limit minimum -36824.1 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1429     def __call__(self):
#    1430         'Return the locations of the ticks'
# -> 1431         self.refresh()
#    1432         return self._locator()
#    1433
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1449     def refresh(self):
#    1450         'Refresh internal information based on current limits.'
# -> 1451         dmin, dmax = self.viewlim_to_dt()
#    1452         self._locator = self.get_locator(dmin, dmax)
#    1453
#
# ~/anaconda3/envs/datamites/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1200                              'often happens if you pass a non-datetime '
#    1201                              'value to an axis that has datetime units'
# -> 1202                              .format(vmin))
#    1203         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1204
#
# ValueError: view limit minimum -36824.1 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
Counter(forecastOne.Stock)
# Out:
# Counter({'ENGINE OIL': 3802,
#          'POLISH': 1245,
#          'CONSUMABLES': 1595,
#          'COOLANT OIL': 70,
#          'CHAIN LUBRICATION': 3441,
#          '4 WAY SWITCH': 2,
#          '3M OIL': 1628,
#          'GENERAL SERVICE': 2142,
#          'OIL FILTER': 821,
#          'INDICATOR': 110,
#          'HEAD REST': 56,
#          'VALVE GUIDE': 63,
#          'TIMMING CHAIN': 78,
#          'FOOT REST': 99,
#          'LOW BEAM BULB': 12,
#          'VALVE GRAINDING': 63,
#          'DISC PAD': 575,
#          'LOADING GEAR': 53,
#          'PACKING KIT': 56,
#          'TIMMING CHAIN PAD': 73,
#          'TENSIONER': 79,
#          'CLUTCH BELL REST': 21,
#          'CLUTCH ASSEMBLY': 212,
#          'VALVE KIT': 66,
#          'SPARK PLUG': 421,
#          'ONE WAY CLUTCH': 5,
#          'BORE KIT': 53,
#          'AIR FILTER': 1715,
#          'HEAD RUBBER': 18,
#          'CLUTCH CABLE': 263,
#          'CRANK SHAFT': 50,
#          'BRAKE ADJUSTMENT': 7,
#          'BRAKE SHOE': 965,
#          'AIR FILTER CHECKUP': 467,
#          'DRUM BOLT WASHER': 5,
#          'TANK CLEANING': 20,
#          'FORK BEND': 49,
#          'GEAR SHAFT': 64,
#          'CLUTCH COVER GASKET': 190,
#          'INDICATOR BULB': 28,
#          'GEAR LEVER': 23,
#          'HANDLEBAR': 33,
#          'CRASH GUARD': 35,
#          'FORK OIL SEAL': 58,
#          'FORK OIL': 95,
#          'SIDE SHIELD': 13,
#          'VISIOR': 38,
#          'FORK CONE SET': 65,
#          'HEAD LIGHT DOOM': 34,
#          'TANK ASSEMBLY': 4,
#          'Clutch cable': 5,
#          'DISC LEVER': 30,
#          'CARBURETOR CLEANING': 2,
#          'SEAT COVER': 119,
#          'BUZZER': 38,
#          'TAIL LAMP BULB': 101,
#          'DISC OIL': 991,
#          'DISC OVERHUAL': 79,
#          'MASTER ASSEMBLY': 20,
#          'CHAIN COVER RUBBER': 5,
#          'ENGINE GUARD': 46,
#          'CLUTCH CAM ': 8,
#          'DOOM': 11,
#          'WHEEL RUBBER': 521,
#          'TIMMING CHAIN OVERHUAL': 4,
#          'SERVICE': 12,
#          'FORK OVERHUAL': 72,
#          'bore kit': 3,
#          'ENGINE BEARING': 50,
#          'CRANK RESET': 49,
#          'CARBURETOR DIAPHRAGM RUBBER': 20,
#          'ENGINE LABOUR': 49,
#          'CLUTCH LEVER': 98,
#          'DRUM BOLT': 103,
#          'LOCK SET': 27,
#          'RIGHT SHIELD CAP': 1,
#          'SWITCH': 49,
#          'SHOCK ABSORBER': 10,
#          'STEP HOLDER': 8,
#          'ACCELATOR CABLE': 51,
#          'JALL SCREW': 3,
#          'TANK COVER': 134,
#          'CLUTCH OVERHUAL': 163,
#          'HANDLE LOCK': 5,
#          'GRIPPER': 34,
#          'PARKING BULB': 77,
#          'WIND SHIELD': 42,
#          'SPEEDOMETER CAP': 9,
#          'HEAD LIGHT STAY': 13,
#          'LABOUR': 131,
#          'CONE SET': 7,
#          'DOOM SCREW KIT': 11,
#          'DISK PAD': 63,
#          'HEAD LIGHT BULB': 79,
#          'CALIPER ASSEMBLY': 57,
#          'LOCK ARM': 43,
#          'CHAIN OVERHAUL': 284,
#          'CHAIN SPROCKET': 396,
#          'BATTERY CHARGE': 19,
#          'SPEEDOMETER CABLE': 47,
#          'WIRING CHECKUP': 20,
#          'YOKE RUBBER': 4,
#          'TYRE GUARD': 6,
#          'CHAIN SET': 23,
#          'PETROL TUBE': 22,
#          'REAR CALIPER ASSEMBLY': 11,
#          'clutch cable': 72,
#          'MIRROR ADJUSTMENT': 2,
#          'FORK ASSEMBLY': 8,
#          'HORN': 15,
#          'FORK LABOUR': 2,
#          nan: 35,
#          'CLUTCH SWITCH': 39,
#          'SILENCER': 6,
#          'WHEEL BEARING': 31,
#          'SWITCH ': 1,
#          'CHOKE CABLE': 4,
#          'KICKER STOPPER': 13,
#          'FORK OIL AND OIL SEAL': 14,
#          'LADIES FOOT REST': 9,
#          'FOOT REST RUBBER': 2,
#          'SILENCER JALL': 16,
#          'BRAKE CABLE': 24,
#          'DISC PUMP KIT': 104,
#          'RACTIFIER': 18,
#          'SELF MOTOR': 7,
#          'YOKE': 21,
#          'MIRROR': 91,
#          'ONE WAY CLUTCH BUSH KIT': 27,
#          'WASHING': 52,
#          'SIDE SHIELD LOCK': 5,
#          'OIL CAMP O RING': 1,
#          'Clutch CABLE': 1,
#          'TAIL LAMP COVER': 5,
#          'TANK BAG': 10,
#          'BATTERY': 83,
#          'WIND SHIELD STICKER': 12,
#          'LOCK SET BOLT': 5,
#          'STOPPER WELDING': 5,
#          'CAM SHAFT': 16,
#          'LADIES HANDLE': 32,
#          'TAIL LAMP ASSEMBLY': 18,
#          'SPROCKET BEARING': 314,
#          'SILENCER JALI': 4,
#          'FORK': 1,
#          'SPRING': 7,
#          'HEAD O RING': 5,
#          'GEAR LEVER RUBBER': 17,
#          'STAY': 7,
#          'BRAKE LIGHT SWITCH': 59,
#          'BRAKE ROD SPRING': 1,
#          'PAD': 10,
#          'SEAT COWL': 8,
#          'FUEL GUAGE': 5,
#          'HANDLE WEIGHT': 15,
#          'NUMBER PLATE WITH STICKER': 2,
#          'CAM SHAFT SPRING': 1,
#          'PETROL TAP': 24,
#          'INDICATOR SWITCH': 2,
#          'KICKER SPRING': 3,
#          'SILENCER GASKET': 4,
#          'BODY COVER': 1,
#          'BATTERY BELT': 8,
#          'DISC PLATE': 41,
#          'BOTTLE COIL': 2,
#          'ENGINE OIL TOPUP': 5,
#          'PETROL': 13,
#          'MUDGUARD FLOP': 1,
#          'FRONT MUDGUARD': 22,
#          'PETROL PIPE': 6,
#          'BRAKE SWITCH': 2,
#          'TEFLON COATING': 8,
#          'SPEEDOMETER COVER': 2,
#          'STICKER': 2,
#          'ENGINE WORK': 5,
#          'PUNCHER': 4,
#          'STARTER COIL': 27,
#          'VISIOR STICKER': 2,
#          'SIDE SHELD RUBBER': 5,
#          'SELF REALY': 7,
#          'WIRING KIT': 14,
#          'SELF KIT': 1,
#          'VISIOR WITH LABOUR': 1,
#          'HANDLE BAR': 6,
#          'BULB ': 1,
#          'BULB': 11,
#          'SPEEDOMETER': 11,
#          'HEAD LIGHT HOLDER': 6,
#          'MUDGUARD BOLT': 3,
#          'SIDE STAND SPRING': 14,
#          'CHAIN ADJUSTER PLATE': 25,
#          'CDI UNIT': 16,
#          'WIRING LABOUR': 4,
#          'CHAIN LINK LOCK': 3,
#          'WIRING': 4,
#          'CLUTCH ADJUSTMENT': 1,
#          'PLUG ADAPTER': 11,
#          'SHIELD RUBBER': 19,
#          'FUSE BOX': 5,
#          'PLUG ADAPTER RUBBER': 2,
#          'HALF ACCELERATOR': 45,
#          'NUMBER PLATE': 15,
#          'COIL CHECK': 45,
#          'STAND RUBBER': 1,
#          'DISC OIL TOPUP': 10,
#          'DC KIT': 15,
#          'BRAKE LEVER': 7,
#          'BRAKE PEDAL SPRING': 13,
#          'AIR INTAKE': 5,
#          'TOP PLATE': 5,
#          'TANK CAP': 7,
#          'CLUTCH OUTLET PIPE': 1,
#          'SIDE STAND': 17,
#          'GRIP HANDLE': 8,
#          'handle weight': 3,
#          'SPEEDOMETER BULB': 7,
#          'WELDING': 7,
#          'PILOT LIGHT': 5,
#          'SILENCER JALL SCREW': 4,
#          'TUBE': 3,
#          'ENGINE SCREW KIT': 1,
#          'OIL SEAL KIT': 18,
#          'PETROL LOCK': 6,
#          'FLASHER': 4,
#          'BOLT WIELDING': 2,
#          'TYRE': 52,
#          'TYRE REPLACEMENT': 19,
#          'FUSE': 2,
#          'HEAD BORE GASKET': 1,
#          'NUMBER PLATE STICKER': 2,
#          'HEAD LIGHT SWITCH': 42,
#          'BATTERY CLIP': 2,
#          'BRAKE PEDAL RUBBER': 1,
#          'HELMET LOCK': 7,
#          'tyre': 1,
#          'HEAD CAP O RING': 16,
#          'HANDLE GRIPPER': 5,
#          'GRILL': 2,
#          'BEARING SET': 3,
#          'MASTER CYLENDER': 53,
#          'PUMP KIT': 5,
#          'LEVER BOLT': 1,
#          'TAIL LAMP GLASS': 10,
#          'COIL': 3,
#          'GB COVER SCREW': 1,
#          'SIDE LOCK': 5,
#          'CENTER STAND SPRING': 2,
#          'GEAR LEVER BOLT': 6,
#          'ENGINE OIL TANK COVER SEAT LADIES ENGINE GUARD': 1,
#          'DOOM REPLACEMENT': 5,
#          'CLUTCH CAM SPRING': 7,
#          'MAGNET COVER BOLT': 2,
#          'DISC ASSEMBLY': 1,
#          'TANK FOLP': 4,
#          'BRAKE PEDAL': 7,
#          'HANDLE HOLDER': 3,
#          'PACKING': 7,
#          'PAYMENT': 1,
#          'KICKER': 1,
#          'LEVER': 3,
#          'GASKET KIT': 4,
#          'COIL START': 1,
#          'WIND SHIELD RUBBER': 3,
#          'OIL LENSE': 15,
#          'RC CARD': 4,
#          'PLUG': 6,
#          'BALANCING GEAR': 8,
#          'INDICATOR BUZZER': 9,
#          'DRUM': 1,
#          'RIM': 1,
#          'ENGINE RUBBER': 1,
#          'PICKUP COIL': 29,
#          'HALF AXLE': 9,
#          'ENGINE CASE WELDING': 2,
#          'THREADING': 2,
#          'BODY ': 1,
#          'HOLDER STEP': 4,
#          'CARBURETOR SPRING': 1,
#          'CENTER STAND': 1,
#          'AXLE': 2,
#          'BOLT REMOVAL': 1,
#          'RELAY': 1,
#          'GEAR AND GB SHAFT OIL SEAL': 10,
#          'REAR BREAK LIGHT SWITCH': 5,
#          'DOOM CAP': 1,
#          'CRASH GUARD BOLT': 2,
#          'REBORE': 4,
#          'MAGNET COIL': 1,
#          'BRAKE LIGHT SPRING': 3,
#          'EX SHOW ROOM': 4,
#          'REGISTER FEES': 3,
#          'LIFE TIME TAX': 4,
#          'ADD ON FEES': 3,
#          'HEAD LAMP CONTROL': 1,
#          'SWING ARM BUISH KIT': 7,
#          'FLOAT': 2,
#          'ENGINE OVERHUAL': 1,
#          'BC UNIT': 3,
#          'SIDE STAND RUBBER': 1,
#          'SHIELD COVER': 1,
#          'SAREE GUARD': 4,
#          'WHEEL BEND': 18,
#          'SPEEDOMETER STAY': 1,
#          'HANDLEBAR RUBBER': 1,
#          'BRAKE ROD': 2,
#          'BORE': 1,
#          'BULB HOLDER': 1,
#          'WHEEL ALIGNMENT': 5,
#          'REAR FOOT REST': 11,
#          'HALF ENGINE AND CARBORATOR': 1,
#          'COOLANT OIL TOP UP': 6,
#          'ENGINE RE CONDITION': 1,
#          'DOOM SCREW RUBBER': 1,
#          'HEAD LIGHT GRILL': 1,
#          'CHAIN ADJUSTER': 10,
#          'SIDE BOX': 3,
#          'TANK DENT': 4,
#          'COOLANT OIL SENSOR': 4,
#          'YOKE SET': 1,
#          'BRAKE LIGHT SWITCH ': 9,
#          'SPPEDOMETER CABLE': 1,
#          'SPEEDOMETER WORM': 13,
#          'RADIATOR': 1,
#          'YOKE LEVER': 2,
#          'SERVICE AND ONE WAY CLUTCH BUSH KIT': 1,
#          'DISC HOSE PIPE': 2,
#          'SEAT COWL STICKER': 1,
#          'GRILL SET': 1,
#          'ENGINE': 1,
#          'HEAD SENSOR': 3,
#          'GB SHAFT OIL SEAL': 3,
#          'MOBILE HOLDER': 2,
#          'WHEEL ASSMEBLY': 1,
#          'WHEEL BOLT': 2,
#          'CHAIN COVER BOLT': 38,
#          'HEAD CAP LABOUR': 1,
#          'REAR SHOCK ABSORBER': 1,
#          'OIL COOLER PIPE': 1,
#          'BEDDING BOLT': 4,
#          'MAGNET ASSEMBLY': 1,
#          'BEARING': 3,
#          'ENGINE TEM SENSOR': 1,
#          'SPRING AND BREAK SHOE': 2,
#          'FRONT NO PLATE WITH STIKER-': 1,
#          'FUEL WIRING KIT': 1,
#          'BORE GASKET': 1,
#          'HEAD GASKET KIT': 1,
#          'BRAKE RUBBER': 1,
#          'MUDGAURD': 1,
#          'WHEEL AXLE': 1,
#          'MUDGAURD CLAMP': 1,
#          'REGISTER EXPENSES': 1,
#          'REAR TUBE': 3,
#          'MAGNET OVERHUAL': 2,
#          'MAGNET COVER GASKET': 6,
#          'MAGNET COVER PACKING': 1,
#          'CLUTCH YOUCK': 6,
#          'CHAIN PAD': 1,
#          'CLUTCH COVER PACKING': 3,
#          'DISK PLATE': 1,
#          'MAGWHEEL BEND': 1,
#          'TAPPED WELDING': 1,
#          'INTAKE': 1,
#          'FLOAT NEEDLE': 2,
#          'GEAR LEVER WELDING': 1,
#          'CARBURETOR ASSEMBLY': 15,
#          'LEVER RUBBER': 1,
#          'RIM TUBLESS NECK': 1,
#          'RADIATOR OVERHUAL': 1,
#          'LOCK TYPE PETROL TAP': 2,
#          'PETROL FILTER': 5,
#          'CLUTCH CAM SWITCH': 1,
#          'SPROCKET RUBBER': 347,
#          'CASE WELDING': 3,
#          'GEAR BOX OIL': 1,
#          'CLUTCH ROLLERS': 1,
#          'CLUTCH SPRING KIT': 1,
#          'CLUTCH SHOE': 1,
#          'U BUSH': 1,
#          'MAJOR KIT': 2,
#          'MAGNET COIL AND PICKUP COIL': 1,
#          'CONE SET OVERHUAL': 1,
#          'HELMET CABLE': 1,
#          'ONE WAY BODY': 1,
#          'STAND WELDING': 1,
#          'TUBELESS NECK': 4,
#          'SEAT': 2,
#          'COOLANT OIL HOSE PIPE': 1,
#          'INSURANCE': 1,
#          'PULSAR RS 200 ABS': 1,
#          'COOLANT OIL TANK': 1,
#          'FOG LAMP': 4,
#          '8 SIZE BOLT': 1,
#          'GB BOLT': 2,
#          'STOPPER HOLDER': 1,
#          'NUMBER PLATE CLAMP': 6,
#          'SPEEDOMETER CLAMP': 1,
#          'FITTING LABOUR': 1,
#          'VISIOR BOTTOM COVER': 1,
#          'MUDGUARD': 5,
#          'WASHING AND LABOUR': 1,
#          'REAR TAIL LAMP GRILL': 1,
#          'FOG LAMP FITTING': 1,
#          'CLUTCH REPALCEMENT': 1,
#          'STAND LOCK PIN ': 1,
#          'WIRING CHECK WITH LABOR': 1,
#          'OIL SEAL WATER PUMP': 1,
#          'GEAR LEVER ASSEMBLY': 1,
#          'CABLE LOCK': 3,
#          'KICKER RUBBER': 1,
#          '10 SIZE NUT': 2,
#          'MUDGUARD CLAMP': 1,
#          '6004 BEARING': 2,
#          '6303 BEARING': 1,
#          '6202 BEARING': 1,
#          'SHIELD LOCK': 1,
#          'CARBURETOR': 4,
#          'GEAR SHAFT OIL SEAL': 8,
#          'MAGNET COVER STICKER': 1,
#          'ENGINE CASE': 2,
#          'ENGINE CASE BEARING ASSEBLY': 1,
#          'GEAR BOX': 2,
#          'HEAD LIGHT WIRING': 1,
#          'LIGHTING COIL': 1,
#          'LIGHT SWITCH': 2,
#          'STOPPER': 1,
#          'LIGHT RELAY': 2,
#          'COIL LABOUR': 3,
#          'BRAKE BUSH KIT': 1,
#          'GB COVER': 1,
#          'FORK SPRING': 5,
#          'CAHIN PAD SCREW': 1,
#          'SHIELD SQUARE RUBBER': 7,
#          'SIDE STAND BRACKET': 3,
#          'CHOKE SENSOR': 1,
#          'GEAR AND WASHER': 1,
#          'CARBURETOR PLATE': 1,
#          'WIND SHIELD LOGO': 3,
#          'FOG LAMP SET': 1,
#          'ONE WAY CLUTCH BODY': 2,
#          '12 SIZE BOLT': 2,
#          'GB COVER BOLT': 2,
#          'SIDE SWITCH MAGNET': 1,
#          'WASHING AND POLISH': 1,
#          'BUSH KIT': 13,
#          'GRIP SET': 2,
#          'HANDLE WEIGHT BOLT': 1,
#          'SEAT LOCK': 3,
#          'CHAIN COVER BEADING': 7,
#          'FIBER LOCK': 1,
#          'GEAR SHAFT SPRING': 1,
#          'BATTERY TARMINAL': 1,
#          'HANDLE WEIGHT LIGHT': 1,
#          'CALIPER RUBBER KIT': 1,
#          'FUEL TAP': 1,
#          'SILENCER WELDING': 1,
#          'WHEEL NECK': 1,
#          'PILOT LIGHT BULB': 1,
#          'LIGHT FITTING CHARGE': 1,
#          'HEAD LIGHT CLIP': 1,
#          'HANDLEBAR THREADING': 1,
#          'LIGHT FITTING LABOUR': 1,
#          'HANDLE BAR LIGHT': 1,
#          'SIDE STAND MAGNET': 4,
#          'HORN CLIP': 2,
#          'POWER ADAPTER': 1,
#          'TANK LOGO': 2,
#          'MAGWHEEL': 2,
#          'RADIATOR FAN': 1,
#          'HAND GLOUSE': 1,
#          'POSITION LAMP': 1,
#          'FRONT MASK': 3,
#          'OIL PUMP': 2,
#          'HEAD LIGHT RELAY': 2,
#          'PICKUP CHARGES': 1,
#          'COIL OVERHUAL': 1,
#          'O RING KIT': 1,
#          'CASE BEARING': 1,
#          'SIDE STAND BOLT': 1,
#          'SIDE MASK': 1,
#          'FOOT REST ASSEMBLY': 2,
#          'SPEEDOMETER GLASS': 1,
#          'POWER COIL': 1,
#          'HIGH BEAM BULB': 1,
#          'WHEEL ACCELETOR CABLE': 2,
#          'BEARING WIELDING': 1,
#          'OIL COOLER CAP': 1,
#          'FUEL GUAGE OVERHUAL': 1,
#          'FUEL TANK': 1,
#          'TANK  RUBBER': 1,
#          'HEAD STAY': 3,
#          'CRASH GASKET': 1,
#          'MASK': 1,
#          'GEAR LEVER OIL SEAL': 1,
#          'GEAR LEVER BUSH': 1,
#          'WHEEL TUBE': 1,
#          'ONE WAY CLUTCH ASSEMBLY': 1,
#          'SEAT FITTING CHARGE': 1,
#          'SPEEDOMETER FLOP': 1,
#          'WIND SHIELD RUBBER KIT': 1,
#          'HORN FITTING CHARGE': 1,
#          'MAGNET OIL SEAL': 1,
#          'HELMET': 1})

# %%
labelEncoder= LabelEncoder()

# %%
# forecastOne.Stock = labelEncoder.fit_transform(forecastOne.Stock.astype(str))

# %%
forecastOne.head()
# Out:
#         Date        Stock
# 0 2017-05-30   ENGINE OIL
# 1 2017-06-02   ENGINE OIL
# 2 2017-06-02       POLISH
# 3 2017-06-02  CONSUMABLES
# 4 2017-06-02  COOLANT OIL

# %%
from collections import Counter

# %%
Counter(forecastOne.Stock)
# Out:
# Counter({'ENGINE OIL': 3802,
#          'POLISH': 1245,
#          'CONSUMABLES': 1595,
#          'COOLANT OIL': 70,
#          'CHAIN LUBRICATION': 3441,
#          '4 WAY SWITCH': 2,
#          '3M OIL': 1628,
#          'GENERAL SERVICE': 2142,
#          'OIL FILTER': 821,
#          'INDICATOR': 110,
#          'HEAD REST': 56,
#          'VALVE GUIDE': 63,
#          'TIMMING CHAIN': 78,
#          'FOOT REST': 99,
#          'LOW BEAM BULB': 12,
#          'VALVE GRAINDING': 63,
#          'DISC PAD': 575,
#          'LOADING GEAR': 53,
#          'PACKING KIT': 56,
#          'TIMMING CHAIN PAD': 73,
#          'TENSIONER': 79,
#          'CLUTCH BELL REST': 21,
#          'CLUTCH ASSEMBLY': 212,
#          'VALVE KIT': 66,
#          'SPARK PLUG': 421,
#          'ONE WAY CLUTCH': 5,
#          'BORE KIT': 53,
#          'AIR FILTER': 1715,
#          'HEAD RUBBER': 18,
#          'CLUTCH CABLE': 263,
#          'CRANK SHAFT': 50,
#          'BRAKE ADJUSTMENT': 7,
#          'BRAKE SHOE': 965,
#          'AIR FILTER CHECKUP': 467,
#          'DRUM BOLT WASHER': 5,
#          'TANK CLEANING': 20,
#          'FORK BEND': 49,
#          'GEAR SHAFT': 64,
#          'CLUTCH COVER GASKET': 190,
#          'INDICATOR BULB': 28,
#          'GEAR LEVER': 23,
#          'HANDLEBAR': 33,
#          'CRASH GUARD': 35,
#          'FORK OIL SEAL': 58,
#          'FORK OIL': 95,
#          'SIDE SHIELD': 13,
#          'VISIOR': 38,
#          'FORK CONE SET': 65,
#          'HEAD LIGHT DOOM': 34,
#          'TANK ASSEMBLY': 4,
#          'Clutch cable': 5,
#          'DISC LEVER': 30,
#          'CARBURETOR CLEANING': 2,
#          'SEAT COVER': 119,
#          'BUZZER': 38,
#          'TAIL LAMP BULB': 101,
#          'DISC OIL': 991,
#          'DISC OVERHUAL': 79,
#          'MASTER ASSEMBLY': 20,
#          'CHAIN COVER RUBBER': 5,
#          'ENGINE GUARD': 46,
#          'CLUTCH CAM ': 8,
#          'DOOM': 11,
#          'WHEEL RUBBER': 521,
#          'TIMMING CHAIN OVERHUAL': 4,
#          'SERVICE': 12,
#          'FORK OVERHUAL': 72,
#          'bore kit': 3,
#          'ENGINE BEARING': 50,
#          'CRANK RESET': 49,
#          'CARBURETOR DIAPHRAGM RUBBER': 20,
#          'ENGINE LABOUR': 49,
#          'CLUTCH LEVER': 98,
#          'DRUM BOLT': 103,
#          'LOCK SET': 27,
#          'RIGHT SHIELD CAP': 1,
#          'SWITCH': 49,
#          'SHOCK ABSORBER': 10,
#          'STEP HOLDER': 8,
#          'ACCELATOR CABLE': 51,
#          'JALL SCREW': 3,
#          'TANK COVER': 134,
#          'CLUTCH OVERHUAL': 163,
#          'HANDLE LOCK': 5,
#          'GRIPPER': 34,
#          'PARKING BULB': 77,
#          'WIND SHIELD': 42,
#          'SPEEDOMETER CAP': 9,
#          'HEAD LIGHT STAY': 13,
#          'LABOUR': 131,
#          'CONE SET': 7,
#          'DOOM SCREW KIT': 11,
#          'DISK PAD': 63,
#          'HEAD LIGHT BULB': 79,
#          'CALIPER ASSEMBLY': 57,
#          'LOCK ARM': 43,
#          'CHAIN OVERHAUL': 284,
#          'CHAIN SPROCKET': 396,
#          'BATTERY CHARGE': 19,
#          'SPEEDOMETER CABLE': 47,
#          'WIRING CHECKUP': 20,
#          'YOKE RUBBER': 4,
#          'TYRE GUARD': 6,
#          'CHAIN SET': 23,
#          'PETROL TUBE': 22,
#          'REAR CALIPER ASSEMBLY': 11,
#          'clutch cable': 72,
#          'MIRROR ADJUSTMENT': 2,
#          'FORK ASSEMBLY': 8,
#          'HORN': 15,
#          'FORK LABOUR': 2,
#          nan: 35,
#          'CLUTCH SWITCH': 39,
#          'SILENCER': 6,
#          'WHEEL BEARING': 31,
#          'SWITCH ': 1,
#          'CHOKE CABLE': 4,
#          'KICKER STOPPER': 13,
#          'FORK OIL AND OIL SEAL': 14,
#          'LADIES FOOT REST': 9,
#          'FOOT REST RUBBER': 2,
#          'SILENCER JALL': 16,
#          'BRAKE CABLE': 24,
#          'DISC PUMP KIT': 104,
#          'RACTIFIER': 18,
#          'SELF MOTOR': 7,
#          'YOKE': 21,
#          'MIRROR': 91,
#          'ONE WAY CLUTCH BUSH KIT': 27,
#          'WASHING': 52,
#          'SIDE SHIELD LOCK': 5,
#          'OIL CAMP O RING': 1,
#          'Clutch CABLE': 1,
#          'TAIL LAMP COVER': 5,
#          'TANK BAG': 10,
#          'BATTERY': 83,
#          'WIND SHIELD STICKER': 12,
#          'LOCK SET BOLT': 5,
#          'STOPPER WELDING': 5,
#          'CAM SHAFT': 16,
#          'LADIES HANDLE': 32,
#          'TAIL LAMP ASSEMBLY': 18,
#          'SPROCKET BEARING': 314,
#          'SILENCER JALI': 4,
#          'FORK': 1,
#          'SPRING': 7,
#          'HEAD O RING': 5,
#          'GEAR LEVER RUBBER': 17,
#          'STAY': 7,
#          'BRAKE LIGHT SWITCH': 59,
#          'BRAKE ROD SPRING': 1,
#          'PAD': 10,
#          'SEAT COWL': 8,
#          'FUEL GUAGE': 5,
#          'HANDLE WEIGHT': 15,
#          'NUMBER PLATE WITH STICKER': 2,
#          'CAM SHAFT SPRING': 1,
#          'PETROL TAP': 24,
#          'INDICATOR SWITCH': 2,
#          'KICKER SPRING': 3,
#          'SILENCER GASKET': 4,
#          'BODY COVER': 1,
#          'BATTERY BELT': 8,
#          'DISC PLATE': 41,
#          'BOTTLE COIL': 2,
#          'ENGINE OIL TOPUP': 5,
#          'PETROL': 13,
#          'MUDGUARD FLOP': 1,
#          'FRONT MUDGUARD': 22,
#          'PETROL PIPE': 6,
#          'BRAKE SWITCH': 2,
#          'TEFLON COATING': 8,
#          'SPEEDOMETER COVER': 2,
#          'STICKER': 2,
#          'ENGINE WORK': 5,
#          'PUNCHER': 4,
#          'STARTER COIL': 27,
#          'VISIOR STICKER': 2,
#          'SIDE SHELD RUBBER': 5,
#          'SELF REALY': 7,
#          'WIRING KIT': 14,
#          'SELF KIT': 1,
#          'VISIOR WITH LABOUR': 1,
#          'HANDLE BAR': 6,
#          'BULB ': 1,
#          'BULB': 11,
#          'SPEEDOMETER': 11,
#          'HEAD LIGHT HOLDER': 6,
#          'MUDGUARD BOLT': 3,
#          'SIDE STAND SPRING': 14,
#          'CHAIN ADJUSTER PLATE': 25,
#          'CDI UNIT': 16,
#          'WIRING LABOUR': 4,
#          'CHAIN LINK LOCK': 3,
#          'WIRING': 4,
#          'CLUTCH ADJUSTMENT': 1,
#          'PLUG ADAPTER': 11,
#          'SHIELD RUBBER': 19,
#          'FUSE BOX': 5,
#          'PLUG ADAPTER RUBBER': 2,
#          'HALF ACCELERATOR': 45,
#          'NUMBER PLATE': 15,
#          'COIL CHECK': 45,
#          'STAND RUBBER': 1,
#          'DISC OIL TOPUP': 10,
#          'DC KIT': 15,
#          'BRAKE LEVER': 7,
#          'BRAKE PEDAL SPRING': 13,
#          'AIR INTAKE': 5,
#          'TOP PLATE': 5,
#          'TANK CAP': 7,
#          'CLUTCH OUTLET PIPE': 1,
#          'SIDE STAND': 17,
#          'GRIP HANDLE': 8,
#          'handle weight': 3,
#          'SPEEDOMETER BULB': 7,
#          'WELDING': 7,
#          'PILOT LIGHT': 5,
#          'SILENCER JALL SCREW': 4,
#          'TUBE': 3,
#          'ENGINE SCREW KIT': 1,
#          'OIL SEAL KIT': 18,
#          'PETROL LOCK': 6,
#          'FLASHER': 4,
#          'BOLT WIELDING': 2,
#          'TYRE': 52,
#          'TYRE REPLACEMENT': 19,
#          'FUSE': 2,
#          'HEAD BORE GASKET': 1,
#          'NUMBER PLATE STICKER': 2,
#          'HEAD LIGHT SWITCH': 42,
#          'BATTERY CLIP': 2,
#          'BRAKE PEDAL RUBBER': 1,
#          'HELMET LOCK': 7,
#          'tyre': 1,
#          'HEAD CAP O RING': 16,
#          'HANDLE GRIPPER': 5,
#          'GRILL': 2,
#          'BEARING SET': 3,
#          'MASTER CYLENDER': 53,
#          'PUMP KIT': 5,
#          'LEVER BOLT': 1,
#          'TAIL LAMP GLASS': 10,
#          'COIL': 3,
#          'GB COVER SCREW': 1,
#          'SIDE LOCK': 5,
#          'CENTER STAND SPRING': 2,
#          'GEAR LEVER BOLT': 6,
#          'ENGINE OIL TANK COVER SEAT LADIES ENGINE GUARD': 1,
#          'DOOM REPLACEMENT': 5,
#          'CLUTCH CAM SPRING': 7,
#          'MAGNET COVER BOLT': 2,
#          'DISC ASSEMBLY': 1,
#          'TANK FOLP': 4,
#          'BRAKE PEDAL': 7,
#          'HANDLE HOLDER': 3,
#          'PACKING': 7,
#          'PAYMENT': 1,
#          'KICKER': 1,
#          'LEVER': 3,
#          'GASKET KIT': 4,
#          'COIL START': 1,
#          'WIND SHIELD RUBBER': 3,
#          'OIL LENSE': 15,
#          'RC CARD': 4,
#          'PLUG': 6,
#          'BALANCING GEAR': 8,
#          'INDICATOR BUZZER': 9,
#          'DRUM': 1,
#          'RIM': 1,
#          'ENGINE RUBBER': 1,
#          'PICKUP COIL': 29,
#          'HALF AXLE': 9,
#          'ENGINE CASE WELDING': 2,
#          'THREADING': 2,
#          'BODY ': 1,
#          'HOLDER STEP': 4,
#          'CARBURETOR SPRING': 1,
#          'CENTER STAND': 1,
#          'AXLE': 2,
#          'BOLT REMOVAL': 1,
#          'RELAY': 1,
#          'GEAR AND GB SHAFT OIL SEAL': 10,
#          'REAR BREAK LIGHT SWITCH': 5,
#          'DOOM CAP': 1,
#          'CRASH GUARD BOLT': 2,
#          'REBORE': 4,
#          'MAGNET COIL': 1,
#          'BRAKE LIGHT SPRING': 3,
#          'EX SHOW ROOM': 4,
#          'REGISTER FEES': 3,
#          'LIFE TIME TAX': 4,
#          'ADD ON FEES': 3,
#          'HEAD LAMP CONTROL': 1,
#          'SWING ARM BUISH KIT': 7,
#          'FLOAT': 2,
#          'ENGINE OVERHUAL': 1,
#          'BC UNIT': 3,
#          'SIDE STAND RUBBER': 1,
#          'SHIELD COVER': 1,
#          'SAREE GUARD': 4,
#          'WHEEL BEND': 18,
#          'SPEEDOMETER STAY': 1,
#          'HANDLEBAR RUBBER': 1,
#          'BRAKE ROD': 2,
#          'BORE': 1,
#          'BULB HOLDER': 1,
#          'WHEEL ALIGNMENT': 5,
#          'REAR FOOT REST': 11,
#          'HALF ENGINE AND CARBORATOR': 1,
#          'COOLANT OIL TOP UP': 6,
#          'ENGINE RE CONDITION': 1,
#          'DOOM SCREW RUBBER': 1,
#          'HEAD LIGHT GRILL': 1,
#          'CHAIN ADJUSTER': 10,
#          'SIDE BOX': 3,
#          'TANK DENT': 4,
#          'COOLANT OIL SENSOR': 4,
#          'YOKE SET': 1,
#          'BRAKE LIGHT SWITCH ': 9,
#          'SPPEDOMETER CABLE': 1,
#          'SPEEDOMETER WORM': 13,
#          'RADIATOR': 1,
#          'YOKE LEVER': 2,
#          'SERVICE AND ONE WAY CLUTCH BUSH KIT': 1,
#          'DISC HOSE PIPE': 2,
#          'SEAT COWL STICKER': 1,
#          'GRILL SET': 1,
#          'ENGINE': 1,
#          'HEAD SENSOR': 3,
#          'GB SHAFT OIL SEAL': 3,
#          'MOBILE HOLDER': 2,
#          'WHEEL ASSMEBLY': 1,
#          'WHEEL BOLT': 2,
#          'CHAIN COVER BOLT': 38,
#          'HEAD CAP LABOUR': 1,
#          'REAR SHOCK ABSORBER': 1,
#          'OIL COOLER PIPE': 1,
#          'BEDDING BOLT': 4,
#          'MAGNET ASSEMBLY': 1,
#          'BEARING': 3,
#          'ENGINE TEM SENSOR': 1,
#          'SPRING AND BREAK SHOE': 2,
#          'FRONT NO PLATE WITH STIKER-': 1,
#          'FUEL WIRING KIT': 1,
#          'BORE GASKET': 1,
#          'HEAD GASKET KIT': 1,
#          'BRAKE RUBBER': 1,
#          'MUDGAURD': 1,
#          'WHEEL AXLE': 1,
#          'MUDGAURD CLAMP': 1,
#          'REGISTER EXPENSES': 1,
#          'REAR TUBE': 3,
#          'MAGNET OVERHUAL': 2,
#          'MAGNET COVER GASKET': 6,
#          'MAGNET COVER PACKING': 1,
#          'CLUTCH YOUCK': 6,
#          'CHAIN PAD': 1,
#          'CLUTCH COVER PACKING': 3,
#          'DISK PLATE': 1,
#          'MAGWHEEL BEND': 1,
#          'TAPPED WELDING': 1,
#          'INTAKE': 1,
#          'FLOAT NEEDLE': 2,
#          'GEAR LEVER WELDING': 1,
#          'CARBURETOR ASSEMBLY': 15,
#          'LEVER RUBBER': 1,
#          'RIM TUBLESS NECK': 1,
#          'RADIATOR OVERHUAL': 1,
#          'LOCK TYPE PETROL TAP': 2,
#          'PETROL FILTER': 5,
#          'CLUTCH CAM SWITCH': 1,
#          'SPROCKET RUBBER': 347,
#          'CASE WELDING': 3,
#          'GEAR BOX OIL': 1,
#          'CLUTCH ROLLERS': 1,
#          'CLUTCH SPRING KIT': 1,
#          'CLUTCH SHOE': 1,
#          'U BUSH': 1,
#          'MAJOR KIT': 2,
#          'MAGNET COIL AND PICKUP COIL': 1,
#          'CONE SET OVERHUAL': 1,
#          'HELMET CABLE': 1,
#          'ONE WAY BODY': 1,
#          'STAND WELDING': 1,
#          'TUBELESS NECK': 4,
#          'SEAT': 2,
#          'COOLANT OIL HOSE PIPE': 1,
#          'INSURANCE': 1,
#          'PULSAR RS 200 ABS': 1,
#          'COOLANT OIL TANK': 1,
#          'FOG LAMP': 4,
#          '8 SIZE BOLT': 1,
#          'GB BOLT': 2,
#          'STOPPER HOLDER': 1,
#          'NUMBER PLATE CLAMP': 6,
#          'SPEEDOMETER CLAMP': 1,
#          'FITTING LABOUR': 1,
#          'VISIOR BOTTOM COVER': 1,
#          'MUDGUARD': 5,
#          'WASHING AND LABOUR': 1,
#          'REAR TAIL LAMP GRILL': 1,
#          'FOG LAMP FITTING': 1,
#          'CLUTCH REPALCEMENT': 1,
#          'STAND LOCK PIN ': 1,
#          'WIRING CHECK WITH LABOR': 1,
#          'OIL SEAL WATER PUMP': 1,
#          'GEAR LEVER ASSEMBLY': 1,
#          'CABLE LOCK': 3,
#          'KICKER RUBBER': 1,
#          '10 SIZE NUT': 2,
#          'MUDGUARD CLAMP': 1,
#          '6004 BEARING': 2,
#          '6303 BEARING': 1,
#          '6202 BEARING': 1,
#          'SHIELD LOCK': 1,
#          'CARBURETOR': 4,
#          'GEAR SHAFT OIL SEAL': 8,
#          'MAGNET COVER STICKER': 1,
#          'ENGINE CASE': 2,
#          'ENGINE CASE BEARING ASSEBLY': 1,
#          'GEAR BOX': 2,
#          'HEAD LIGHT WIRING': 1,
#          'LIGHTING COIL': 1,
#          'LIGHT SWITCH': 2,
#          'STOPPER': 1,
#          'LIGHT RELAY': 2,
#          'COIL LABOUR': 3,
#          'BRAKE BUSH KIT': 1,
#          'GB COVER': 1,
#          'FORK SPRING': 5,
#          'CAHIN PAD SCREW': 1,
#          'SHIELD SQUARE RUBBER': 7,
#          'SIDE STAND BRACKET': 3,
#          'CHOKE SENSOR': 1,
#          'GEAR AND WASHER': 1,
#          'CARBURETOR PLATE': 1,
#          'WIND SHIELD LOGO': 3,
#          'FOG LAMP SET': 1,
#          'ONE WAY CLUTCH BODY': 2,
#          '12 SIZE BOLT': 2,
#          'GB COVER BOLT': 2,
#          'SIDE SWITCH MAGNET': 1,
#          'WASHING AND POLISH': 1,
#          'BUSH KIT': 13,
#          'GRIP SET': 2,
#          'HANDLE WEIGHT BOLT': 1,
#          'SEAT LOCK': 3,
#          'CHAIN COVER BEADING': 7,
#          'FIBER LOCK': 1,
#          'GEAR SHAFT SPRING': 1,
#          'BATTERY TARMINAL': 1,
#          'HANDLE WEIGHT LIGHT': 1,
#          'CALIPER RUBBER KIT': 1,
#          'FUEL TAP': 1,
#          'SILENCER WELDING': 1,
#          'WHEEL NECK': 1,
#          'PILOT LIGHT BULB': 1,
#          'LIGHT FITTING CHARGE': 1,
#          'HEAD LIGHT CLIP': 1,
#          'HANDLEBAR THREADING': 1,
#          'LIGHT FITTING LABOUR': 1,
#          'HANDLE BAR LIGHT': 1,
#          'SIDE STAND MAGNET': 4,
#          'HORN CLIP': 2,
#          'POWER ADAPTER': 1,
#          'TANK LOGO': 2,
#          'MAGWHEEL': 2,
#          'RADIATOR FAN': 1,
#          'HAND GLOUSE': 1,
#          'POSITION LAMP': 1,
#          'FRONT MASK': 3,
#          'OIL PUMP': 2,
#          'HEAD LIGHT RELAY': 2,
#          'PICKUP CHARGES': 1,
#          'COIL OVERHUAL': 1,
#          'O RING KIT': 1,
#          'CASE BEARING': 1,
#          'SIDE STAND BOLT': 1,
#          'SIDE MASK': 1,
#          'FOOT REST ASSEMBLY': 2,
#          'SPEEDOMETER GLASS': 1,
#          'POWER COIL': 1,
#          'HIGH BEAM BULB': 1,
#          'WHEEL ACCELETOR CABLE': 2,
#          'BEARING WIELDING': 1,
#          'OIL COOLER CAP': 1,
#          'FUEL GUAGE OVERHUAL': 1,
#          'FUEL TANK': 1,
#          'TANK  RUBBER': 1,
#          'HEAD STAY': 3,
#          'CRASH GASKET': 1,
#          'MASK': 1,
#          'GEAR LEVER OIL SEAL': 1,
#          'GEAR LEVER BUSH': 1,
#          'WHEEL TUBE': 1,
#          'ONE WAY CLUTCH ASSEMBLY': 1,
#          'SEAT FITTING CHARGE': 1,
#          'SPEEDOMETER FLOP': 1,
#          'WIND SHIELD RUBBER KIT': 1,
#          'HORN FITTING CHARGE': 1,
#          'MAGNET OIL SEAL': 1,
#          'HELMET': 1})
